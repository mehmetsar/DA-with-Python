# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("data.csv")
dfgdp = pd.read_csv("gdp-csv-.csv")

# %%
dfgdp.head(20)<
# Out:
#    Unnamed: 0 Gross domestic product 2017  Unnamed: 2          Unnamed: 3  \
# 0         NaN                         NaN         NaN                 NaN
# 1         NaN                         NaN         NaN                 NaN
# 2         NaN                     Ranking         NaN             Economy
# 3         NaN                         NaN         NaN                 NaN
# 4         USA                           1         NaN       United States
# 5         CHN                           2         NaN               China
# 6         JPN                           3         NaN               Japan
# 7         DEU                           4         NaN             Germany
# 8         IND                           5         NaN               India
# 9         GBR                           6         NaN      United Kingdom
# 10        FRA                           7         NaN              France
# 11        BRA                           8         NaN              Brazil
# ...

# %%
dfgdp = dfgdp[["Gross domestic product 2017","Unnamed: 3","Unnamed: 4"]]
dfgdp.head(10)
# Out:
#    Gross domestic product 2017      Unnamed: 3    Unnamed: 4
# 2                      Ranking         Economy   US dollars)
# 3                          NaN             NaN           NaN
# 4                            1   United States   19,485,394
# 5                            2           China   12,237,700
# 6                            3           Japan    4,872,415
# 7                            4         Germany    3,693,204
# 8                            5           India    2,650,725
# 9                            6  United Kingdom    2,637,866
# 10                           7          France    2,582,501
# 11                           8          Brazil    2,053,595

# %%
df = df.dropna()
dfgdp = dfgdp.drop([0,1], axis=0)

# %%
df.head()
# Out:
#         location  iso_code        date total_vaccinations  people_vaccinated  \
# 95   Afghanistan       AFG  2021-05-27             593313           479574.0
# 102  Afghanistan       AFG  2021-06-03             630305           481800.0
# 166       Africa  OWID_AFR  2021-02-03             347149            38746.0
# 167       Africa  OWID_AFR  2021-02-04             390474            38746.0
# 168       Africa  OWID_AFR  2021-02-05             446986            38746.0
#
#      people_fully_vaccinated  daily_vaccinations_raw daily_vaccinations  \
# 95                  113739.0                  2859.0               6487
# 102                 148505.0                  4015.0               5285
# 166                      5.0                 52022.0              45937
# 167                      5.0                 43325.0              51671
# 168                      5.0                 56512.0              59446
#
#      total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13526 entries, 95 to 32940
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             13526 non-null  object
#  1   iso_code                             13526 non-null  object
#  2   date                                 13526 non-null  object
#  3   total_vaccinations                   13526 non-null  object
#  4   people_vaccinated                    13526 non-null  float64
#  5   people_fully_vaccinated              13526 non-null  float64
#  6   daily_vaccinations_raw               13526 non-null  float64
#  7   daily_vaccinations                   13526 non-null  object
#  8   total_vaccinations_per_hundred       13526 non-null  float64
#  9   people_vaccinated_per_hundred        13526 non-null  float64
#  10  people_fully_vaccinated_per_hundred  13526 non-null  float64
# ...

# %%
df.sample(20)
# Out:
#             location  iso_code        date total_vaccinations  \
# 22363         Norway       NOR  2021-03-23             806967
# 24462        Romania       ROU  2021-03-11            2019757
# 24761         Russia       RUS  2021-06-09           31605719
# 17273      Lithuania       LTU  2021-06-20            2092371
# 13000      Hong Kong       HKG  2021-03-06              84033
# 9428          Europe  OWID_EUR  2021-03-16           92517640
# 32494          World  OWID_WRL  2021-02-16          182696710
# 20467        Namibia       NAM  2021-06-12             100793
# 16334         Latvia       LVA  2021-02-14              37604
# 24436        Romania       ROU  2021-02-13            1084096
# 13165        Hungary       HUN  2021-02-02             322306
# 24522        Romania       ROU  2021-05-10            6095252
# 10401         France       FRA  2021-04-01           12008029
# 12829    High income  OWID_HIC  2021-06-16          868884095
# ...

# %%
dfTurkey=df[df["location"] == "Turkey"]

# %%
dfTurkey.head(10)
# Out:
#       location iso_code        date total_vaccinations  people_vaccinated  \
# 30110   Turkey      TUR  2021-02-12            3404354          3067822.0
# 30111   Turkey      TUR  2021-02-13            3709896          3253005.0
# 30112   Turkey      TUR  2021-02-14            3825101          3336164.0
# 30113   Turkey      TUR  2021-02-15            4182027          3608148.0
# 30114   Turkey      TUR  2021-02-16            4630784          3984622.0
# 30115   Turkey      TUR  2021-02-17            5223602          4477432.0
# 30116   Turkey      TUR  2021-02-18            5895295          5028179.0
# 30117   Turkey      TUR  2021-02-19            6361699          5384983.0
# 30118   Turkey      TUR  2021-02-20            6533510          5503094.0
# 30119   Turkey      TUR  2021-02-21            6571830          5517993.0
#
#        people_fully_vaccinated  daily_vaccinations_raw daily_vaccinations  \
# 30110                 336532.0                558229.0             120650
# ...

# %%
plt.subplots(figsize=(10,10))
sns.lineplot(x = "date",   y = "people_vaccinated", data = dfTurkey)
plt.xticks(rotation=45);
